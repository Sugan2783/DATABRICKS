# %%
dbutils.fs.put("/Volumes/dev/bronze/transactions/bad_records.csv", "custId,amount,address"
               )

# %%
bad_records = [
    "123,abc,123 Main St",         # amount is not numeric
    ",100,456 Elm St",             # custId is missing
    "456,200,",                    # address is missing
    "789,300,789 Oak St,extra",    # extra column
    "xyz,400,101 Pine St"          # custId is not numeric
]

df_cust = dbutils.fs.put("/Volumes/dev/bronze/transactions/bad_records1.csv", "custId,amount,address\n" + "\n".join(bad_records))

# %%
print(df_cust)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
import delta.table as DeltaTable

df = spark.DeltaTable.forPath("")
