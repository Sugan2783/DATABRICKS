# %%
df = spark.read.option("header", True).option("inferSchema", True).csv("/Volumes/workspace/default/emp/src_DEPT_FF.csv")
display(df)

# %%
df.write.saveAsTable("dev.bronze.dept")

# %%
# %sql
describe extended dev.bronze.dept;

# %%
# %sql
update dev.bronze.dept set department_name = "Admin" where department_id = 10;

# %%
# %sql
select * from dev.bronze.dept;

# %%
# %sql
select * from dev.bronze.dept version as of 0;

# %%
# %sql
RESTORE TABLE dev.bronze.dept TO VERSION AS OF 0;

# %%
# %sql
select * from dev.bronze.dept;

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;

VACUUM dev.bronze.dept RETAIN 0 HOURS;

# %%
# %sql
VACUUM dev.bronze.dept RETAIN 0 HOURS;

# %%
# %sql
describe history dev.bronze.dept;

# %%
# %sql
convert to delta dev.bronze.dept_parquet;

# %%
df.write.format("parquet").option("path","/Volumes/workspace/default/emp/dept_parquet").saveAsTable("dev.bronze.dept_parquet")

# %%
# %sql
select * from
