# %%
df_cptcodes = spark.read.format("delta").load('/Volumes/dev/bronze/transactions/cptcodes.parquet/')
df_cptcodes.display()

# %%
df_cptcodes.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/cptcodes.csv')

# %%
df_cptcodescsv = spark.read.format("csv").option("header", True).option("inferSchema", True).option("sep", ",").load('/Volumes/dev/bronze/transactions/cptcodes.csv')
df_cptcodescsv.display()

# %%
df_departments = spark.read.format("parquet").load('/Volumes/dev/bronze/transactions/departments.parquet/')
df_departments.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/departments.csv')
df_departmentscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/departments.csv')
df_departmentscsv.display()

# %%
df_encounters = spark.read.format("delta").load('/Volumes/dev/bronze/transactions/encounters.parquet/')
df_encounters.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/encounters.csv')
df_encounterscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/encounters.csv')
df_encounterscsv.display()

# %%
df_claims = spark.read.format("delta").load('/Volumes/dev/bronze/transactions/hospital1_claim_data/')
df_claims.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/hospital1_claim_data.csv')
df_claimscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/hospital1_claim_data.csv')
df_claimscsv.display()

# %%
df_patients = spark.read.format("delta").load('/Volumes/dev/bronze/transactions/patients.parquet/')
df_patients.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/patients.csv')
df_patientscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/patients.csv')
df_patientscsv.display()

# %%
df_providers = spark.read.format("delta").load('/Volumes/dev/bronze/transactions/providers.parquet/')
df_providers.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/providers.csv')
df_providerscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/providers.csv')
df_providerscsv.display()

# %%
df_transactions= spark.read.format("delta").load('/Volumes/dev/bronze/transactions/transactions.parquet/')
df_transactions.write.format("csv").option("header", True).option("sep", ",").mode("overwrite").save('/Volumes/dev/bronze/transactions/transactions.csv')
df_transactionscsv = spark.read.format("csv").option("header", True).option("inferSchema", True).load('/Volumes/dev/bronze/transactions/transactions.csv')
df_transactionscsv.display()
