# %%
import pandas as pd

# %%
df = pd.read_csv("/Volumes/prod/bronze/projectdata/providers.csv")
print(df)

df_patients = spark.createDataFrame(data = df, schema = df_schema)
df_patients.display()

# %%
df_patients.schema.fields

# %%
from pyspark.sql.types import *

# %%
df_patients = spark.createDataFrame(data = df, schema = df_schema)
df_patients.display()

# %%
df_schema = StructType([StructField('ProviderID', StringType(), True),
 StructField('FirstName', StringType(), True),
 StructField('LastName', StringType(), True),
 StructField('Specialization', StringType(), True),
 StructField('DeptID', StringType(), True),
 StructField('NPI', IntegerType(), True)])

# %%
df_patients.schema.fields
