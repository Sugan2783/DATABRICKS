# %%
from pyspark.sql.functions import *
from pyspark.sql.functions import *

df_cust = spark.read.format("json").option("multiline", True).load('/Volumes/workspace/default/emp/json_data.json')
df_cust.display()

df_parsed = df_cust.select("id", "name","address.city".alias('details'))

df_parsed.display()
