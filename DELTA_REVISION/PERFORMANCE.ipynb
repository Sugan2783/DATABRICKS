# %%
# %sql
describe extended dev.bronze.claims

# %%
# %sql
analyze table dev.bronze.claims compute statistics;

# %%
# %sql
explain cost
select * from dev.bronze.claims;

# %%
# %sql
cache select * from dev.bronze.claims;

# %%
# %sql
CACHE TABLE dev.bronze.claims;
