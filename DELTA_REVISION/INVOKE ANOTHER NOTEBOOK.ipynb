# %%
import pandas as pd
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.functions import udf

# %%
source_path = '/Volumes/bigdata/bdata/customer/customer_feedback.parquet'

# %%
def read_file(source_path):
    src_df = pd.read_parquet(source_path)
    src_df.head(100)
    return src_df

df = read_file(source_path)

df_udf = udf(read_file, StringType())
